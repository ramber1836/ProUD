# %%
# beijing
from collections import defaultdict
fname = 'log_decision_dim_bj'
scores = defaultdict(list)
with open(fname, 'r') as fin:
    for line in fin.readlines():
        if line.startswith('testing'):
            item = line.strip().split(' ')
            scores[item[1]].append(item[-1])
for k, v in scores.items():
    print k, len(v)
    for i in range(len(v)/5):
        print '\t'.join(v[5*i:5*i+5])
    print
print
# Out:
# Recall: 35
# 0.800235051725889	0.81789294989916	0.8230147560250142	0.7932125186808084	0.8219265535903426
# 0.8269467941556274	0.8032094717139914	0.8171384628777876	0.8375241218206352	0.7991613586570131
# 0.7850147270062826	0.8157165450298167	0.8061113448731156	0.8368276722624454	0.8208528605214666
# 0.8437631491127523	0.8226520218801237	0.8315462631128393	0.7989872462674656	0.849059067628154
# 0.8229276998302404	0.8254088013812916	0.8471003032457451	0.8207803136924885	0.8204030701818024
# 0.808432843400415	0.781590516678516	0.7871621131440345	0.8274546219584742	0.7908620014219179
# 0.8012942354289694	0.8439807895996866	0.8151942078611744	0.8249880297732186	0.8119876380203421
#
# Prec: 35
# 0.4844739592941032	0.5300223780957933	0.47229021997968396	0.5204291453268092	0.5219474440717945
# 0.48938691396187534	0.50457561615867	0.499840244248793	0.48258132477239096	0.5208416075650119
# 0.5429239460929425	0.4675998702497692	0.48009885760702375	0.47270328085172647	0.5135527677420526
# ...

# %%
from collections import defaultdict
fname = 'log_decision_reg_nyc_10'
scores = defaultdict(list)
with open(fname, 'r') as fin:
    for line in fin.readlines():
        if line.startswith('testing'):
            item = line.strip().split(' ')
            scores[item[1]].append(item[-1])
for k, v in scores.items():
    print k, len(v)
    for i in range(len(v)/10):
        print '\t'.join(v[10*i:10*i+10])
        #print
    print
print
# Out:
# Recall: 70
# 0.7378857837181045	0.7593195625759417	0.7559659781287971	0.7454678007290401	0.7446415552855407	0.7364277035236938	0.6772296476306197	0.7093074119076549	0.7057594167679222	0.7493074119076549
# 0.6762089914945322	0.7407533414337789	0.7101336573511543	0.755722964763062	0.7097448359659781	0.7471202916160389	0.7460510328068044	0.7460024301336573	0.7462940461725395	0.6767436208991494
# 0.7535844471445929	0.7703523693803159	0.7592223572296476	0.764228432563791	0.7401215066828676	0.7594653705953828	0.7433778857837181	0.7430862697448359	0.768554070473876	0.7422114216281895
# 0.7678736330498177	0.6648845686512758	0.7469744835965978	0.7770109356014581	0.7470230862697448	0.7320534629404617	0.6775698663426488	0.7478007290400972	0.7216524908869988	0.7738031591737545
# 0.7857594167679223	0.808602673147023	0.7951397326852977	0.8053462940461725	0.7925151883353584	0.6706196840826245	0.6702308626974484	0.8036938031591737	0.8056379100850547	0.8003888213851762
# ...

# %%
# beijing
from collections import defaultdict
fname = 'log_itemset_nyc'
scores = defaultdict(list)
with open(fname, 'r') as fin:
    for line in fin.readlines():
        if line.startswith('testing'):
            item = line.strip().split(' ')
            scores[item[1]].append(item[-1])
for k, v in scores.items():
    print k, len(v)
    print '\t'.join(v)
    print
print
# Out:
# Recall: 5
# 0.47236938031591735	0.47421628189550424	0.47348724179829893	0.4566707168894289	0.46789793438639127
#
# Prec: 5
# 0.1863841212004986	0.18447372898980924	0.18417271627344223	0.1874513715710723	0.18775231594344222
#
# F1: 5
# 0.26729922992299227	0.2656194702311273	0.2651930693743109	0.2657991513437058	0.2679749478079332
#
# AUC: 5
# 0.5427648884972818	0.5395327561848107	0.5386630156361006	0.5379016337984974	0.5426532954264391
